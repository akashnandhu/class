# %%
x=10   #int
print(type(x))

x=10.0  #float
print(type(x))

x=False   #bool
print(type(x))

x="anju"   #str
print(type(x))

x=20
y=2
print(x//y)   #/ divide but float   //divide

x=10
print(type(x))

z=float(x)
print(type(x))
print(x)

num="20"
x=10
num=int(num)
print(type(num))
print(num+x)

num=0.00000070
x=bool(num)
print(type(x))
print(x)

x=5
if x==5:
    print(x)

x=5
if x==4:
    print(x)
else:
    print("you have more than 4 mango")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# 10
# <class 'int'>
# <class 'int'>
# 10
# <class 'int'>
# 30
# <class 'bool'>
# True
# 5
# you have more than 4 mango

# %%
x=5
if x==1:
    print("1 mangoes")
elif x==2:
    print("2 mangoes")
elif x==3:
    print("3 mangoes")
elif x==4:
    print("4 mangoes")
elif x==5:
    print("5 mangoes")
else:
    pass
# Out:
# 5 mangoes

# %%
name="anju"
print(name)
print(name.title())
print(name.upper())
print(name.lower())
print(name.capitalize())
print(name.strip())
print(name.lstrip())
print(name.rstrip())
print(name.replace("anju","akhil"))
print(name.count("n"))
print(name.find("u"))
print(name.lower())
print(name.isalpha())
print(name.isdigit())
# Out:
# anju
# Anju
# ANJU
# anju
# Anju
# anju
# anju
# anju
# akhil
# 1
# 3
# anju
# False

# %%
    #data types
int,float,bool,str,tuple,list,set,dict  #json
# Out:
# (int, float, bool, str, tuple, list, set, dict)

# %%
#tuple function
name="anju"
print(name.count("n"))
print(name.index("j"))
# Out:
# 1
# 2

# %%
#list function
name=[1,2,3,4,5]
print(name.insert(0,"b"))
print(name.append("0"))
# Out:
# None
# None

# %%
# str---immutable,sequence of character,index based
# tuple--immutable,sequence of character,index based
# list---mutable,sequence of character,index based
# set---mutable,not a index based,duplication not allowed
# dict---mutable,not a index based,duplication not allowed

# %%
def anju():
    num1=int(input("Enter a number : "))
    num2=int(input("Enter a number : "))
    print(num1+num2)
anju()
anju()
anju()
# Out:
# 5
# 5
# 5

# %%
# parametrized functions

def add(x,y):
    print(x+y)
add(10,20)
# Out:
# 30

# %%
# function witn return type

def add(x,y):
    total=x+y
    return total


num1=int(input("Enter a number : "))
num2=int(input("Enter a number : "))
z=add(num1,num2)
print(z)
# Out:
# 10

# %%
#optionaL Patrametrized

def add(x,y,z=1):
    total=x+y+z
    return total
num1=int(input("enter a number"))
num2=int(input("enter a number"))
num3=int(input("enter a number"))
abi=add(num1,num2)
print(abi)
# Out:
# 10

# %%
# function return a function= closure

def anju():
    def add(x,y):#9
        return x+y  #9
    return add
       
abi=anju()
print(abi(4,5))
# Out:
# 9

# %%
#recursive function
            #functiion call itself
#call back function
            #function call another function

# %%
#scope
        #two types
                #global and local

#local

        #declare any veriable inside a function or method or a block..


#global
        #declare any veriable outside a function or method or a block..


i="anish"    #global
def loop():
    global i
    i=20
    j="anju"    #local
    print(i)
    print(j)

# %%
#class
        #blueprint
#object

        #instance

# self   ----- keyword
#constructor --- for memory allocation
#distructor ---- for deallocation

#inheritance ---parent child relation
#tyrps of inheritance

        #heierarchial inheri
        #multiple inheri
        #multilevel inheri


#access modifier

        #private  (__)  #double underscore
        #public   
        #protected  (_) #single underscore


#overloading
        #same name different parameters same class

class demo:
    def hello(self,*args):
        ans=0
        for i in args:
            ans += i
        return ans
x=demo()
print(x.hello(4,5,4,3,56,6,7,9,6,54,34,3,33,3,3,33,3,3,3,4,5,53,3,3,43,))
#overriding
        #same name same parameters but different class
        
class demo:
    def hello(self):
        print("hello")
    def hai(self):
        print("hai")
class child(demo):
    def hello(self):
        print("hello")
x=child()
x.hello()
# Out:
# 383
# hello
